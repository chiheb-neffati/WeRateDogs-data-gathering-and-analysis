# %% [markdown]
# # WeRateDogs Data Analysis Report
# ## Introduction
# In this project I am going to walk you through the data analysis process of the tweet archive of Twitter user @dog_rates, also known as ”WeRateDogs”.
# WeRateDogs is a Twitter account that rates people’s dogs with a humorous comment about the dog and today I am going to walk through the process of collecting data from the archive using the twitter API along with other provided data.but before we begin, we first want to set a goal on our analysis, and to do that we have to ask ourselves, what do we want to look for ?, therefore, I will answer these questions below and see what we can find from this data:
# <li>Does the dog breed affect the rating or the number of other users' retweets ?</li>
# <li>What are the most popular names ?</li>
# <li>How does the dog stages affect the ratings ?</li>
# <li>How does rating affect favorites and retweets ?</li>

# %% [markdown]
# ## Does the dog breed affect the rating or the number of other users' retweets ?
# To answer this question, I will use the rating numerator and breed columns along with the retweets count we gathered using Twitter API.<br>
# After Grouping our data by breed, we get the graphs bellow:<br>
# <b>These figures signify the 10 least and 10 most rated breeds of dogs</b>
# ![image](data:image/png;base64,...)

# %% [markdown]
# <b>These figures signify the average retweet count of the 10 least and 10 most rated breeds of dogs</b>
# ![image](data:image/png;base64,...)

# %% [markdown]
# ### Let's Conclude
# As we can see from the two figures above us, dog breeds with higher ratings (top 10) can reach up to 5000 retweets or more on average, with the majority of them breaking the 3000 retweets(average) wall, contrary to the least 10 rated breads that struggle to get to 1500 retweets.
# ## What are the most popular names along with their average ratings ?
# To tackle this question, we will use the name column to calculate the number of occurences of each name, this way, we can find the names that are most popular.<br>
# After doing so, we get this graph:
# ![image](data:image/png;base64,...)

# %% [markdown]
# ### Let's Conclude
# From the graph above, we can say that the most commonly used names in "this data" are common normal names like charlie, Daisy, Lola, Toby etc..., although it is expected, we can't say anything conclusive since we are working with a not-so-big data.
# ## How does the dog stages affect the ratings ?
# In each rating, a dog stage can be used to further describe the dog, these are doggo, floofer, pupper, and puppo, but does it affect the rating ?, to find out, I calculated the average ratings of each stage along with the average rating of those with no dog stage.<br>
# By doing so, I got the following Bar graph:
# ![image](data:image/png;base64,...)

# %% [markdown]
# ### Let's conclude
# From the dog stages bar graph we just created, we can comfortably conclude that dog stages and rating are definitely related, since ratings with no stage are significantly lower than it's counters, with puppo and floofer having the highest average rating.
# ## How does rating affect favorites and retweets ?
# in this section, I will use the data I gathered using the Twitter API(i.e the favorites count and retweets count) to find out if there is any form of correlation between those and the ratings.<br>
# In this case, I made a scatter plot to see if there is any correlation between these values:
# ![image](data:image/png;base64,...)

# %% [markdown]
# As expected, ratings and like and/or retweets are positively correlated, with higher ratings having drastically higher count of likes and retweets.
# ## General Conclusion
# In this dataset, I focused Mainly on these variables :
# <li>Ratings</li>
# <li>Dog names</li>
# <li>Dog breeds</li>
# <li>Likes count</li>
# <li>Retweets count</li>
# And, I got to discover that some of them have some type realtion exist between them (for example, the ratings and like/retweets count in the last graph), but I can't say that any of these relations are definit, for example, in the last question, are there higher retweet counts just because of the higher rating or because of the breed of the dog, No one can deny that some breeds are more popular than others, also we saw that some breeds have higher average rating, so it might be an indirect cause.<br>
# Finally, I would like to say that there is plenty more insights to get from this data, I chose to only work on some of them mainly out of interest and also to keep it brief.
